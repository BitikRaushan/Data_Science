# %%
import pandas as pd

df = pd.read_csv("Indian_Food_Nutrition_Processed.csv")
print(df.head(1))
# Out:
#               Dish Name  Calories (kcal)  Carbohydrates (g)  Protein (g)  \
# 0  Hot tea (Garam Chai)            16.14               2.58         0.39
#
#    Fats (g)  Free Sugar (g)  Fibre (g)  Sodium (mg)  Calcium (mg)  Iron (mg)  \
# 0      0.53            2.58        0.0         3.12          14.2       0.02
#
#    Vitamin C (mg)  Folate (µg)
# 0             0.5          1.8

# %%
print(df.isnull().sum())
# Out:
# Dish Name             0
# Calories (kcal)       0
# Carbohydrates (g)     0
# Protein (g)           0
# Fats (g)              0
# Free Sugar (g)        0
# Fibre (g)             0
# Sodium (mg)           0
# Calcium (mg)          0
# Iron (mg)             0
# Vitamin C (mg)       82
# Folate (µg)          82
# dtype: int64

# %%
df = df.dropna()
print(df.head(1))
# Out:
#               Dish Name  Calories (kcal)  Carbohydrates (g)  Protein (g)  \
# 0  Hot tea (Garam Chai)            16.14               2.58         0.39
#
#    Fats (g)  Free Sugar (g)  Fibre (g)  Sodium (mg)  Calcium (mg)  Iron (mg)  \
# 0      0.53            2.58        0.0         3.12          14.2       0.02
#
#    Vitamin C (mg)  Folate (µg)
# 0             0.5          1.8

# %%
print(df.columns)
# Out:
# Index(['Dish Name', 'Calories (kcal)', 'Carbohydrates (g)', 'Protein (g)',
#        'Fats (g)', 'Fibre (g)', 'Calcium (mg)', 'Iron (mg)', 'Vitamin C (mg)',
#        'Folate (µg)'],
#       dtype='str')

# %%
# df = df.drop(["Free Sugar (g)", "Sodium (mg)"], axis=1)
df.head(2)
# Out:
#               Dish Name  Calories (kcal)  Carbohydrates (g)  Protein (g)  \
# 0  Hot tea (Garam Chai)            16.14               2.58         0.39
# 1        Instant coffee            23.16               3.65         0.64
#
#    Fats (g)  Fibre (g)  Calcium (mg)  Iron (mg)  Vitamin C (mg)
# 0      0.53        0.0         14.20       0.02            0.50
# 1      0.75        0.0         20.87       0.06            1.51

# %%
df
# Out:
#                                              Dish Name  Calories (kcal)  \
# 0                                 Hot tea (Garam Chai)            16.14
# 1                                       Instant coffee            23.16
# 2                                       Espreso coffee            51.54
# 3                                             Iced tea            10.34
# 4                          Raw mango drink (Aam panna)            35.92
# ..                                                 ...              ...
# 927                                         Bread roll           435.46
# 928                                   Soya seekh kebab           115.05
# 929                       Classic seasoned black beans            28.78
# 930                                  Maa chaane ki dal           344.67
# 931  Garlic chickpea soup (Lahasun aur chane ka sho...            89.53
#
#      Carbohydrates (g)  Protein (g)  Fats (g)  Fibre (g)  Calcium (mg)  \
# ...

# %%
df.to_csv("clean_data.csv", index=False)
